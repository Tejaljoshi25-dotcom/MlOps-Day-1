# %%
import pandas as pd
import numpy as np

df=pd.read_csv("D:\\MlOps Day 1\\data\\data.csv")
df.head()
# Out:
# Running cells with 'MlOps-Day-1_env (Python 3.14.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n MlOps-Day-1_env ipykernel --update-deps --force-reinstall'
